# %% [markdown]
# ###### Imports and Settings

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# # Nativity by Age for the GNRC Senior Centers
#
# This data is not available on MySidewalk, where these senior center profiles are hosted. This notebook contains the API pulls and the data cleaning process necessary to include this as outside data in these profiles.

# %%
GNRC = ['161', #Stewart
       '125', #Montgomery
       '083', #Houston
       '085', #Humphreys
       '043', #Dickson
       '021', #Cheatham
       '147', #Robertson
       '165', #Sumner
       '037', #Davidson
       '189', #Wilson
       '169', #Trousdale
       '187', #Williamson
       '149'] #Rutherford

# %%
api_key = '24fc7d81b74510d599f702dbd408fb18e1466d81'

# %% [markdown]
# Maybe this series: B05002_021E
# place of birth by nativity and citizenship status - Europe, Asia, Africa, Oceania, Latin America, Northern America - NO AGE
#
# Maybe this series: B05006_001E
# place of birth for the foreign-born population in the US
#
# Yes - place of birth for the foreign-born population in the US, then in MySidewalk can do foreign-born population by age... although the age groups are inconsistent so might pull that from ACS as well to keep with 65+.

# %%
#'B05006_001E' - 'B05006_049E', total - eastern asia total
data_appended = []
for i in GNRC:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME", "GEO_ID",'B05006_001E','B05006_002E','B05006_003E','B05006_004E',
              'B05006_005E','B05006_006E','B05006_007E','B05006_008E',
              'B05006_009E','B05006_010E','B05006_011E','B05006_012E',
              'B05006_013E','B05006_014E','B05006_015E','B05006_016E',
              'B05006_017E','B05006_018E','B05006_019E','B05006_020E',
              'B05006_021E','B05006_022E','B05006_023E','B05006_024E',
              'B05006_025E','B05006_026E','B05006_027E','B05006_028E',
              'B05006_029E','B05006_030E','B05006_031E','B05006_032E',
              'B05006_033E','B05006_034E','B05006_035E','B05006_036E',
              'B05006_037E','B05006_038E','B05006_039E','B05006_040E',
              'B05006_041E','B05006_042E','B05006_043E','B05006_044E',
              'B05006_045E','B05006_046E','B05006_047E','B05006_048E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','total','total_europe','eur_northerneurope','eur_n_ireland',
                 'eur_n_denmark','eur_n_norway','eur_n_sweden','eur_n_UKwcrowndepend',
                 'eur_n_UKnoEnglandScotland','eur_n_england','eur_n_scotland',
                 'eur_n_other','eur_westerneurope','eur_w_austria','eur_w_belgium','eur_w_france',
                 'eur_w_germany','eur_w_netherlands','eur_w_switzerland','eur_w_other',
                 'eur_southerneurope','eur_s_greece','eur_s_italy','eur_s_portugal','eur_s_azoresislands',
                 'eur_s_spain','eur_s_other','eur_easterneurope','eur_e_albania','eur_e_belarus',
                 'eur_e_bosniaandherzegovina','eur_e_bulgaria','eur_e_croatia','eur_e_czechrepublicandslovakia',
                 'eur_e_hungary','eur_e_latvia','eur_e_lithuania','eur_e_northmacedonia','eur_e_moldova',
                 'eur_e_poland','eur_e_romania','eur_e_russia','eur_e_serbia','eur_e_ukraine','eur_e_other',
                 'eur_nec','total_asia','asia_easternasia','StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = 'GNRC'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
first = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %%
# 'B05006_049E' - 'B05006_090E', china - asia, nec
data_appended = []
for i in GNRC:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME", "GEO_ID",'B05006_049E','B05006_050E','B05006_051E','B05006_052E',
              'B05006_053E','B05006_054E','B05006_055E','B05006_056E','B05006_057E','B05006_058E',
              'B05006_059E','B05006_060E','B05006_061E','B05006_062E','B05006_063E','B05006_064E',
              'B05006_065E','B05006_066E','B05006_067E','B05006_068E','B05006_069E','B05006_070E',
              'B05006_071E','B05006_072E','B05006_073E','B05006_074E','B05006_075E','B05006_076E',
              'B05006_077E','B05006_078E','B05006_079E','B05006_080E','B05006_081E','B05006_082E',
              'B05006_083E','B05006_084E','B05006_085E','B05006_086E','B05006_087E','B05006_088E',
              'B05006_089E','B05006_090E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','as_e_china','as_e_chinanohongkongortaiwan',
                 'as_e_hongkong','as_e_taiwan','as_e_japan','as_e_korea','as_e_other',
                 'asia_southcentral','as_sc_afghanistan','as_sc_bangladesh','as_sc_india',
                 'as_sc_iran','as_sc_kazakhstan','as_sc_nepal','as_sc_pakistan','as_sc_srilanka',
                 'as_sc_uzbekistan','as_sc_other','asia_southeastern','as_se_burma','as_se_cambodia',
                 'as_se_indonesia','as_se_laos','as_se_malaysia','as_se_philippines','as_se_singapore',
                 'as_se_thailand','as_se_vietnam','as_se_other','asia_western','as_w_armenia','as_w_iraq',
                 'as_w_israel','as_w_jordan','as_w_kuwait','as_w_lebanon','as_w_saudiarabia','as_w_syria',
                 'as_w_turkey','as_w_yemen','as_w_other','asia_nec',
                 'StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = 'GNRC'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
second = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %%
# 'B05006_091' - 'B05006_128E', total, africa - oceania nec
data_appended = []
for i in GNRC:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME", "GEO_ID",'B05006_091E','B05006_092E',
              'B05006_093E','B05006_094E','B05006_095E','B05006_096E','B05006_097E','B05006_098E',
              'B05006_099E','B05006_100E','B05006_101E','B05006_102E','B05006_103E','B05006_104E',
              'B05006_105E','B05006_106E','B05006_107E','B05006_108E','B05006_109E','B05006_110E',
              'B05006_111E','B05006_112E','B05006_113E','B05006_114E','B05006_115E','B05006_116E',
              'B05006_117E','B05006_118E','B05006_119E','B05006_120E','B05006_121E','B05006_122E',
              'B05006_123E','B05006_124E','B05006_125E','B05006_126E','B05006_127E','B05006_128E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','africa_total','africa_easternafrica',
                 'af_ea_eritrea','af_ea_ethiopia','af_ea_kenya','af_ea_somalia',
                 'af_ea_uganda','af_ea_zimbabwe','af_ea_other','africa_middleafrica',
                 'af_ma_cameroon','af_ma_congo','af_ma_democraticrepublicofcongosaire','af_ma_other',
                 'africa_northernafrica','af_na_egypt','af_na_morocco','af_na_sudan',
                 'af_na_other','africa_southernafrica','af_sa_southafrica','af_sa_other',
                 'africa_westernafrica','af_w_caboverde','af_w_ghana','af_w_liberia',
                 'af_w_nigeria','af_w_senegal','af_w_sierraleone','af_w_other','africa_nec',
                 'oceania','oc_australianewzelandsubregion','oc_anz_australia','oc_anz_other',
                 'oc_fiji','oc_micronesia','oceania_nec',
                 'StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = 'GNRC'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
third = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %%
# 'B05006_129E' - 'B05006_168E', total americas, other northern america
data_appended = []
for i in GNRC:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME", "GEO_ID",'B05006_129E','B05006_130E',
              'B05006_131E','B05006_132E','B05006_133E','B05006_134E','B05006_135E','B05006_136E',
              'B05006_137E','B05006_138E','B05006_139E','B05006_140E','B05006_141E','B05006_142E',
              'B05006_143E','B05006_144E','B05006_145E','B05006_146E','B05006_147E','B05006_148E',
              'B05006_149E','B05006_150E','B05006_151E','B05006_152E','B05006_153E']#,'5006_154E']#,
#              'B05006_155E','B05006_156E','B05006_157E','B05006_158E','B05006_159E','B05006_1160E',
#               'B05006_167E','B05006_168E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','americas_total','americas_latinamerica',
                 'am_la_caribbean','am_la_ca_bahamas','am_la_ca_barbados','am_la_ca_cuba',
                 'am_la_ca_dominica','am_la_ca_dominicanrepublic','am_la_ca_grenada','am_la_ca_haiti',
                 'am_la_ca_jamaica','am_la_ca_stvincentandthegrenadines','am_la_ca_trinidadandtobago','am_la_ca_westindies',
                 'am_la_ca_other','am_la_centralamerica','am_la_cent_belize','am_la_cent_costarica',
                 'am_la_cent_elsalvador','am_la_cent_guatemala','am_la_cent_honduras','am_la_cent_mexico',
                 'am_la_cent_nicaragua','am_la_cent_panama','am_la_cent_other',
                 #'am_la_southamerica',
                 #'am_la_sa_argentina','am_la_sa_bolivia','am_la_sa_brazil',
                 #'am_la_sa_chile',
#                  'am_la_sa_columbia','am_la_sa_ecuador','am_la_sa_guyana','am_la_sa_peru',
#                  'am_la_sa_uruguay','am_la_sa_venezuela','am_la_sa_other','americas_northernamerica',
#                  'm_na_canada','am_na_other',
                 'StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = 'GNRC'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
fourth = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %%
# 'B05006_129E' - 'B05006_168E', total americas, other northern america
data_appended = []
for i in GNRC:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME", "GEO_ID",'B05006_154E','B05006_155E',
               'B05006_156E','B05006_157E','B05006_158E','B05006_159E',
               'B05006_160E','B05006_161E','B05006_162E','B05006_163E',
               'B05006_164E','B05006_165E','B05006_166E','B05006_167E','B05006_168E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','am_la_southamerica','am_la_sa_argentina',
                 'am_la_sa_bolivia','am_la_sa_brazil','am_la_sa_chile','am_la_sa_columbia',
                 'am_la_sa_ecuador','am_la_sa_guyana','am_la_sa_peru','am_la_sa_uruguay',
                 'am_la_sa_venezuela','am_la_sa_other','americas_northernamerica','m_na_canada','am_na_other',
                 'StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = 'GNRC'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
fourth = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %%
third.head(13)
# Out:
#                           County           GEOID africa_total  \
# 0      Stewart County, Tennessee  0500000US47161            0
# 1   Montgomery County, Tennessee  0500000US47125         1050
# 2      Houston County, Tennessee  0500000US47083            0
# 3    Humphreys County, Tennessee  0500000US47085            0
# 4      Dickson County, Tennessee  0500000US47043           37
# 5     Cheatham County, Tennessee  0500000US47021            5
# 6    Robertson County, Tennessee  0500000US47147          106
# 7       Sumner County, Tennessee  0500000US47165          417
# 8     Davidson County, Tennessee  0500000US47037        17775
# 9       Wilson County, Tennessee  0500000US47189         1136
# 10   Trousdale County, Tennessee  0500000US47169            0
# 11  Williamson County, Tennessee  0500000US47187          680
# 12  Rutherford County, Tennessee  0500000US47149         2378
#
#    africa_easternafrica af_ea_eritrea af_ea_ethiopia af_ea_kenya  \
# ...
