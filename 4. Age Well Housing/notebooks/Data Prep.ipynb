# %% [markdown]
# ###### Imports and Settings

# %%
import pandas as pd
import numpy as np
import requests
import pickle
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)

# %% [markdown]
# # Age Well
#
# The following code outlines data collection, formatting, cleaning, and calculations for a data request for Age Well Tennessee.
#
# The following data is collected:
# + total population 65+
# + income
# + caregiver for grandkids
# + own vs rent
# + cost burden
# + living alone
# + educational attainment
# + poverty
#
# Most of this was directly requested, but some was added on by research staff as the request asked for other compelling data to make a case for the need for affordable housing for seniors.

# %%
with open('api_keys.pkl', 'rb') as keys_file:
        keys_dict_2 = pickle.load(keys_file)

# %%
#create a variable that contains your api key
api_key = keys_dict_2['CENSUS']

# %%
REGION = ['161', #Stewart
       '125', #Montgomery
       '083', #Houston
       '085', #Humphreys
       '043', #Dickson
       '021', #Cheatham
       '147', #Robertson
       '165', #Sumner
       '037', #Davidson
       '189', #Wilson
       '169', #Trousdale
       '187', #Williamson
       '149', #Rutherford
       '119'] #Maury

# %% [markdown]
# ## API Calls

# %% [markdown]
# ID's 1-47

# %%
data_appended = []
for i in REGION:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME", "GEO_ID",'B01001_001E','B01001_001E','B01001_020E','B01001_021E','B01001_022E','B01001_023E','B01001_024E','B01001_025E','B01001_044E',
               'B01001_045E','B01001_046E','B01001_047E','B01001_048E','B01001_049E','B17001_001E','B17001_002E','B17001_015E','B17001_016E','B17001_029E',
               'B17001_030E','B15001_001E','B15001_035E','B15001_036E','B15001_037E','B15001_038E','B15001_039E','B15001_040E','B15001_041E','B15001_042E',
               'B15001_076E','B15001_077E','B15001_078E','B15001_079E','B15001_080E','B15001_081E','B15001_082E','B15001_083E','B09020_001E','B09020_001E',
               'B09020_015E','B09020_018E','B10051_001E','B10051_002E','B10051_005E','B25093_001E','B25093_023E','B25093_027E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','pop','agebysex_total_series','age_m_65to66','age_m_67to69','age_m_70to74','age_m_75to79','age_m_80to84','age_m_85+',
                 'age_f_65to66','age_f_67to69','age_f_70to74','age_f_75to79','age_f_80to84','age_f_85+','poverty_total_series','poverty_totalbelowpoverty',
                 'poverty_m65to74','poverty_m75+','poverty_f65to74','poverty_f75+','ed_total_series','ed_m65+','ed_m65+_less9thgrade','ed_m65+9thto12th',
                 'ed_m65+_highschoolgradequivalency','ed_m65+_somecollegenodegree','ed_m65+_associates','ed_m65+_bachelors','ed_m65+_graduateorprofessionaldegree',
                 'ed_f65+','ed_f65+_less9thgrade','ed_f65+9thto12th','ed_f65+_highschoolgradequivalency','ed_f65+_somecollegenodegree','ed_f65+_associates',
                 'ed_f65+_bachelors','ed_f65+_graduateorprofessionaldegree','livealone_total65+_series','livealone_total65+_inhh','livealone_m65+','livealone_f65+',
                 'grandparent_total_responsibilityforgrandchild_series','grandparent_responsibleforgrandchild','grandparent_resposibleforgrandchild_noparent_60+',
                 'housing_total_ownercosts','housing_65+total_ownercosts','housing_65+30to34.9%_ownercosts','StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = '14County'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
callone = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %% [markdown]
# Call Two: ID's 48 - 82 except for 73

# %%
data_appended = []
for i in REGION:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME","GEO_ID",'B25093_028E','B25072_001E','B25072_023E','B25072_027E','B25072_028E','B19055_001E','B19055_002E','B19055_003E','B19037_053E',
               'B19037_054E',
               'B19037_055E','B19037_056E','B19037_057E','B19037_058E','B19037_059E','B19037_060E','B19037_061E','B19037_062E','B19037_063E','B19037_064E',
               'B19037_065E','B19037_066E','B19037_067E','B19037_068E','B19037_069E','B25007_001E','B25007_002E','B25007_009E','B25007_010E',
               'B25007_011E','B25007_012E','B25007_019E','B25007_020E','B25007_021E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','housing_65+35%ormore_ownercosts','housing_total_grossrent','housing_65+total_grossrent','housing_65+30to34.9%_grossrent',
                 'housing_65+35%ormore_grossrent',
                 'socialsecurityhh_total_series','socialsecurityhh_with','socialsecurityhh_without','hhincome_totalhh65+_series','hhincome_65+_lessthan10000',
                 'hhincome_65+_10000to14999','hhincome_65+_15000to19999','hhincome_65+_20000to24999','hhincome_65+_25000to29999','hhincome_65+_30000to34999',
                 'hhincome_65+_35000to39999','hhincome_65+_40000to44999','hhincome_65+_45000to49999','hhincome_65+_50000to59999','hhincome_65+_60000to74999',
                 'hhincome_65+_75000to99999','hhincome_65+_100000to124999','hhincome_65+_125000to149999','hhincome_65+_150000to199999','hhincome_65+_200000+',
                 'tenure_total_agehh_series','tenure_allowneroccupied','tenure_owner_65to74','tenure_owner_75to84','tenure_owner_85+',
                 'tenure_allrenteroccupied','tenure_renter_65to74','tenure_renter_75to84','tenure_renter_85+','StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = '14County'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
calltwo = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %% [markdown]
# ID 73 Median Alone

# %%
data_appended = []
for i in REGION:
    url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+api_key
    predicates= {}
    get_vars= ["NAME","GEO_ID",'B19049_005E']
    predicates["get"]= ",". join(get_vars)
    predicates["for"]= "county:{}".format(i)
    predicates["in"]= "state:47"
    data= requests.get(url_str, params= predicates)
    col_names = ['County', 'GEOID','hhincome_65+_median','StateFIPS','CountyFIPS']
    data=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype = str)
    data['Region'] = '14County'
    data_appended.append(data)
    
data_appended = pd.concat(data_appended)
callthree = data_appended.reset_index(drop = True)
print('Your API call is complete')
# Out:
# Your API call is complete

# %% [markdown]
# ## Median HH Income 65+ Alone

# %%
callthree.head(15)
# Out:
#                           County           GEOID hhincome_65+_median StateFIPS CountyFIPS    Region
# 0      Stewart County, Tennessee  0500000US47161               40956        47        161  14County
# 1   Montgomery County, Tennessee  0500000US47125               44792        47        125  14County
# 2      Houston County, Tennessee  0500000US47083               37872        47        083  14County
# 3    Humphreys County, Tennessee  0500000US47085               40319        47        085  14County
# 4      Dickson County, Tennessee  0500000US47043               39975        47        043  14County
# 5     Cheatham County, Tennessee  0500000US47021               42125        47        021  14County
# 6    Robertson County, Tennessee  0500000US47147               43444        47        147  14County
# 7       Sumner County, Tennessee  0500000US47165               49443        47        165  14County
# 8     Davidson County, Tennessee  0500000US47037               49128        47        037  14County
# 9       Wilson County, Tennessee  0500000US47189               51544        47        189  14County
# 10   Trousdale County, Tennessee  0500000US47169               42530        47        169  14County
# 11  Williamson County, Tennessee  0500000US47187               70350        47        187  14County
# 12  Rutherford County, Tennessee  0500000US47149               51116        47        149  14County
# 13       Maury County, Tennessee  0500000US47119               40857        47        119  14County

# %% [markdown]
# # Merge and Prep the Rest of Database

# %%
callone = callone.drop(columns = ['StateFIPS','CountyFIPS','Region'])

# %%
calltwo = calltwo.drop(columns = ['County'])

# %%
data = callone.merge(calltwo, on = 'GEOID')

# %%
data.head()
# Out:
#                          County           GEOID     pop agebysex_total_series age_m_65to66 age_m_67to69 age_m_70to74 age_m_75to79 age_m_80to84  \
# 0     Stewart County, Tennessee  0500000US47161   13553                 13553          209          272          291          191          113
# 1  Montgomery County, Tennessee  0500000US47125  204992                204992         1684         1912         1930         1315          866
# 2     Houston County, Tennessee  0500000US47083    8201                  8201           73          169          237          164           54
# 3   Humphreys County, Tennessee  0500000US47085   18528                 18528          198          284          502          398          177
# 4     Dickson County, Tennessee  0500000US47043   53289                 53289          615          768         1056          667          460
#
#   age_m_85+ age_f_65to66 age_f_67to69 age_f_70to74 age_f_75to79 age_f_80to84 age_f_85+ poverty_total_series poverty_totalbelowpoverty  \
# 0       129          222          247          345          289          250       120                13336                      1772
# 1       733         2069         1672         2656         1754         1130      1344               200387                     24675
# 2        67           89          176          240          192          153        78                 7865                      1166
# 3        60          417          275          394          509          211       168                18067                      2803
# 4       249          745          887         1139          762          524       641                52660                      6278
#
#   poverty_m65to74 poverty_m75+ poverty_f65to74 poverty_f75+ ed_total_series ed_m65+ ed_m65+_less9thgrade ed_m65+9thto12th  \
# 0              56           16              76           89           10673    1205                   39               94
# 1             357          123             455          378          150053    8440                  457              320
# 2              66           14              71           68            6420     764                   83              102
# 3              42           44              93          189           14524    1619                  132              248
# 4             111          159             309          291           41010    3815                  496              354
#
#   ed_m65+_highschoolgradequivalency ed_m65+_somecollegenodegree ed_m65+_associates ed_m65+_bachelors ed_m65+_graduateorprofessionaldegree ed_f65+  \
# 0                               579                         260                 68               113                                   52    1473
# 1                              2442                        1742                874              1593                                 1012   10625
# 2                               378                          87                  9                76                                   29     928
# 3                               775                         186                 42               131                                  105    1974
# 4                              1633                         581                108               339                                  304    4698
#
#   ed_f65+_less9thgrade ed_f65+9thto12th ed_f65+_highschoolgradequivalency ed_f65+_somecollegenodegree ed_f65+_associates ed_f65+_bachelors  \
# 0                   48              222                               697                         170                 69                63
# 1                  648             1123                              3826                        2074                727              1146
# 2                   68              120                               423                         160                 25                39
# 3                   71              267                               854                         336                 56               225
# 4                  424              690                              2204                         645                193               339
#
#   ed_f65+_graduateorprofessionaldegree livealone_total65+_series livealone_total65+_inhh livealone_m65+ livealone_f65+  \
# 0                                  204                      2678                    2678            226            568
# 1                                 1081                     19065                   19065           1586           3164
# 2                                   93                      1692                    1692            157            289
# 3                                  165                      3593                    3593            235            758
# 4                                  203                      8513                    8513            763           1363
#
#   grandparent_total_responsibilityforgrandchild_series grandparent_responsibleforgrandchild grandparent_resposibleforgrandchild_noparent_60+  \
# 0                                                346                                    101                                               81
# 1                                               4285                                   1800                                              213
# 2                                                203                                    108                                                5
# 3                                                416                                    181                                               26
# 4                                               1144                                    445                                              112
#
#   housing_total_ownercosts housing_65+total_ownercosts housing_65+30to34.9%_ownercosts housing_65+35%ormore_ownercosts housing_total_grossrent  \
# 0                     3953                        1515                              27                             224                    1273
# 1                    45436                        9670                             400                            1477                   29170
# 2                     2322                         851                              23                             162                     597
# 3                     5389                        2048                              72                             336                    1480
# 4                    14891                        4349                             219                             460                    4668
#
#   housing_65+total_grossrent housing_65+30to34.9%_grossrent housing_65+35%ormore_grossrent socialsecurityhh_total_series socialsecurityhh_with  \
# 0                        277                             35                             43                          5226                  2508
# 1                       2049                             84                            992                         74606                 17022
# 2                        130                             10                             38                          2919                  1203
# 3                        312                              0                            122                          6869                  2998
# 4                        879                            164                            210                         19559                  6818
#
#   socialsecurityhh_without hhincome_totalhh65+_series hhincome_65+_lessthan10000 hhincome_65+_10000to14999 hhincome_65+_15000to19999  \
# 0                     2718                       1792                         99                        42                       149
# 1                    57584                      11719                        494                       656                       846
# 2                     1716                        981                         86                        79                       145
# 3                     3871                       2360                        143                       261                       114
# 4                    12741                       5228                        243                       412                       463
#
#   hhincome_65+_20000to24999 hhincome_65+_25000to29999 hhincome_65+_30000to34999 hhincome_65+_35000to39999 hhincome_65+_40000to44999  \
# 0                       172                       102                       155                       138                       166
# 1                       761                      1089                       744                       533                       761
# 2                        44                        81                        39                        48                        71
# 3                       121                        75                       260                       194                       139
# 4                       283                       393                       310                       513                       291
#
#   hhincome_65+_45000to49999 hhincome_65+_50000to59999 hhincome_65+_60000to74999 hhincome_65+_75000to99999 hhincome_65+_100000to124999  \
# 0                       182                        90                       152                       225                          13
# 1                       539                       973                       945                      1533                         682
# 2                        56                        45                        30                       153                          29
# 3                       195                       243                       162                       208                         107
# 4                       241                       502                       518                       412                         302
#
#   hhincome_65+_125000to149999 hhincome_65+_150000to199999 hhincome_65+_200000+ tenure_total_agehh_series tenure_allowneroccupied  \
# 0                          29                          56                   22                      5226                    3953
# 1                         455                         367                  341                     74606                   45436
# 2                           0                          54                   21                      2919                    2322
# 3                          54                          48                   36                      6869                    5389
# 4                          76                          96                  173                     19559                   14891
#
#   tenure_owner_65to74 tenure_owner_75to84 tenure_owner_85+ tenure_allrenteroccupied tenure_renter_65to74 tenure_renter_75to84 tenure_renter_85+  \
# 0                 907                 443              165                     1273                  123                  146                 8
# 1                5815                2714             1141                    29170                 1244                  427               378
# 2                 414                 354               83                      597                   89                   38                 3
# 3                1144                 774              130                     1480                  193                   50                69
# 4                2669                1269              411                     4668                  569                  190               120
#
#   StateFIPS CountyFIPS    Region
# 0        47        161  14County
# 1        47        125  14County
# 2        47        083  14County
# 3        47        085  14County
# 4        47        043  14County

# %% [markdown]
# convert datatypes to integers

# %%
cols = ['pop','agebysex_total_series','age_m_65to66','age_m_67to69','age_m_70to74','age_m_75to79','age_m_80to84','age_m_85+',
        'age_f_65to66','age_f_67to69','age_f_70to74','age_f_75to79','age_f_80to84','age_f_85+','poverty_total_series','poverty_totalbelowpoverty',
        'poverty_m65to74','poverty_m75+','poverty_f65to74','poverty_f75+','ed_total_series','ed_m65+','ed_m65+_less9thgrade','ed_m65+9thto12th',
        'ed_m65+_highschoolgradequivalency','ed_m65+_somecollegenodegree','ed_m65+_associates','ed_m65+_bachelors','ed_m65+_graduateorprofessionaldegree',
        'ed_f65+','ed_f65+_less9thgrade','ed_f65+9thto12th','ed_f65+_highschoolgradequivalency','ed_f65+_somecollegenodegree','ed_f65+_associates',
        'ed_f65+_bachelors','ed_f65+_graduateorprofessionaldegree','livealone_total65+_series','livealone_total65+_inhh','livealone_m65+','livealone_f65+',
        'grandparent_total_responsibilityforgrandchild_series','grandparent_responsibleforgrandchild','grandparent_resposibleforgrandchild_noparent_60+',
        'housing_total_ownercosts','housing_65+total_ownercosts','housing_65+30to34.9%_ownercosts','housing_65+35%ormore_ownercosts','housing_total_grossrent','housing_65+total_grossrent',
        'housing_65+30to34.9%_grossrent','housing_65+35%ormore_grossrent','socialsecurityhh_total_series','socialsecurityhh_with','socialsecurityhh_without',
        'hhincome_totalhh65+_series','hhincome_65+_lessthan10000','hhincome_65+_10000to14999','hhincome_65+_15000to19999','hhincome_65+_20000to24999',
        'hhincome_65+_25000to29999','hhincome_65+_30000to34999','hhincome_65+_35000to39999','hhincome_65+_40000to44999','hhincome_65+_45000to49999',
        'hhincome_65+_50000to59999','hhincome_65+_60000to74999','hhincome_65+_75000to99999','hhincome_65+_100000to124999','hhincome_65+_125000to149999',
        'hhincome_65+_150000to199999','hhincome_65+_200000+','tenure_total_agehh_series','tenure_allowneroccupied','tenure_owner_65to74','tenure_owner_75to84',
        'tenure_owner_85+','tenure_allrenteroccupied','tenure_renter_65to74','tenure_renter_75to84','tenure_renter_85+']
data[cols] = data[cols].astype(int)

# %% [markdown]
# groupby for total region

# %%
region = data[['pop','agebysex_total_series','age_m_65to66','age_m_67to69','age_m_70to74','age_m_75to79','age_m_80to84','age_m_85+',
        'age_f_65to66','age_f_67to69','age_f_70to74','age_f_75to79','age_f_80to84','age_f_85+','poverty_total_series','poverty_totalbelowpoverty',
        'poverty_m65to74','poverty_m75+','poverty_f65to74','poverty_f75+','ed_total_series','ed_m65+','ed_m65+_less9thgrade','ed_m65+9thto12th',
        'ed_m65+_highschoolgradequivalency','ed_m65+_somecollegenodegree','ed_m65+_associates','ed_m65+_bachelors','ed_m65+_graduateorprofessionaldegree',
        'ed_f65+','ed_f65+_less9thgrade','ed_f65+9thto12th','ed_f65+_highschoolgradequivalency','ed_f65+_somecollegenodegree','ed_f65+_associates',
        'ed_f65+_bachelors','ed_f65+_graduateorprofessionaldegree','livealone_total65+_series','livealone_total65+_inhh','livealone_m65+','livealone_f65+',
        'grandparent_total_responsibilityforgrandchild_series','grandparent_responsibleforgrandchild','grandparent_resposibleforgrandchild_noparent_60+',
        'housing_total_ownercosts','housing_65+total_ownercosts','housing_65+30to34.9%_ownercosts','housing_65+35%ormore_ownercosts','housing_total_grossrent','housing_65+total_grossrent',
        'housing_65+30to34.9%_grossrent','housing_65+35%ormore_grossrent','socialsecurityhh_total_series','socialsecurityhh_with','socialsecurityhh_without',
        'hhincome_totalhh65+_series','hhincome_65+_lessthan10000','hhincome_65+_10000to14999','hhincome_65+_15000to19999','hhincome_65+_20000to24999',
        'hhincome_65+_25000to29999','hhincome_65+_30000to34999','hhincome_65+_35000to39999','hhincome_65+_40000to44999','hhincome_65+_45000to49999',
        'hhincome_65+_50000to59999','hhincome_65+_60000to74999','hhincome_65+_75000to99999','hhincome_65+_100000to124999','hhincome_65+_125000to149999',
        'hhincome_65+_150000to199999','hhincome_65+_200000+','tenure_total_agehh_series','tenure_allowneroccupied','tenure_owner_65to74','tenure_owner_75to84',
        'tenure_owner_85+','tenure_allrenteroccupied','tenure_renter_65to74','tenure_renter_75to84','tenure_renter_85+','Region']].groupby('Region').sum()

# %%
region = region.reset_index()

# %%
region
# Out:
#      Region      pop  agebysex_total_series  age_m_65to66  age_m_67to69  age_m_70to74  age_m_75to79  age_m_80to84  age_m_85+  age_f_65to66  \
# 0  14County  2090952                2090952         20309         25712         30994         20455         12123       9129         23385
#
#    age_f_67to69  age_f_70to74  age_f_75to79  age_f_80to84  age_f_85+  poverty_total_series  poverty_totalbelowpoverty  poverty_m65to74  \
# 0         28401         37669         26421         16941      18471               2047989                     226988             4375
#
#    poverty_m75+  poverty_f65to74  poverty_f75+  ed_total_series  ed_m65+  ed_m65+_less9thgrade  ed_m65+9thto12th  ed_m65+_highschoolgradequivalency  \
# 0          2595             7291          6438          1601026   118722                  6875              8367                              32644
#
#    ed_m65+_somecollegenodegree  ed_m65+_associates  ed_m65+_bachelors  ed_m65+_graduateorprofessionaldegree  ed_f65+  ed_f65+_less9thgrade  \
# 0                        23458                6789              23524                                 17065   151288                  7357
#
#    ed_f65+9thto12th  ed_f65+_highschoolgradequivalency  ed_f65+_somecollegenodegree  ed_f65+_associates  ed_f65+_bachelors  \
# 0             13335                              53526                        31407                9077              21034
#
#    ed_f65+_graduateorprofessionaldegree  livealone_total65+_series  livealone_total65+_inhh  livealone_m65+  livealone_f65+  \
# 0                                 15552                     270010                   270010           21089           48026
#
#    grandparent_total_responsibilityforgrandchild_series  grandparent_responsibleforgrandchild  grandparent_resposibleforgrandchild_noparent_60+  \
# 0                                              40851                                    16839                                              2967
#
#    housing_total_ownercosts  housing_65+total_ownercosts  housing_65+30to34.9%_ownercosts  housing_65+35%ormore_ownercosts  housing_total_grossrent  \
# 0                    517790                       135808                             6986                            23692                   276872
#
#    housing_65+total_grossrent  housing_65+30to34.9%_grossrent  housing_65+35%ormore_grossrent  socialsecurityhh_total_series  socialsecurityhh_with  \
# 0                       30704                            2777                           12711                         794662                 208433
#
#    socialsecurityhh_without  hhincome_totalhh65+_series  hhincome_65+_lessthan10000  hhincome_65+_10000to14999  hhincome_65+_15000to19999  \
# 0                    586229                      166512                        8976                       8954                      10754
#
#    hhincome_65+_20000to24999  hhincome_65+_25000to29999  hhincome_65+_30000to34999  hhincome_65+_35000to39999  hhincome_65+_40000to44999  \
# 0                       9214                       9811                       9613                       9104                       9010
#
#    hhincome_65+_45000to49999  hhincome_65+_50000to59999  hhincome_65+_60000to74999  hhincome_65+_75000to99999  hhincome_65+_100000to124999  \
# 0                       8049                      14114                      17192                      19558                        10788
#
#    hhincome_65+_125000to149999  hhincome_65+_150000to199999  hhincome_65+_200000+  tenure_total_agehh_series  tenure_allowneroccupied  \
# 0                         6521                         6129                  8725                     794662                   517790
#
#    tenure_owner_65to74  tenure_owner_75to84  tenure_owner_85+  tenure_allrenteroccupied  tenure_renter_65to74  tenure_renter_75to84  \
# 0                83893                39704             12211                    276872                 17704                  8157
#
#    tenure_renter_85+
# 0               4843

# %% [markdown]
# Recreate lost columns to join back onto df

# %%
region['County'] = 'All'
region['GEOID'] = 'NA'
region['StateFIPS'] = '47'
region['CountyFIPS'] = 'NA'

# %% [markdown]
# ## Concatonate region back on

# %%
dfs = [data, region]
data = pd.concat(dfs).reset_index(drop = True)

# %%
data.tail()
# Out:
#                           County           GEOID      pop  agebysex_total_series  age_m_65to66  age_m_67to69  age_m_70to74  age_m_75to79  \
# 10   Trousdale County, Tennessee  0500000US47169    10910                  10910           143           113           165           155
# 11  Williamson County, Tennessee  0500000US47187   232380                 232380          2259          3016          3778          1950
# 12  Rutherford County, Tennessee  0500000US47149   324139                 324139          2739          3316          3684          2688
# 13       Maury County, Tennessee  0500000US47119    94615                  94615          1065          1324          1962          1030
# 14                           All              NA  2090952                2090952         20309         25712         30994         20455
#
#     age_m_80to84  age_m_85+  age_f_65to66  age_f_67to69  age_f_70to74  age_f_75to79  age_f_80to84  age_f_85+  poverty_total_series  \
# 10            23         24           161           151           182           125           164         48                  9375
# 11          1919       1071          2562          2925          4457          3113          1924       1603                231518
# 12          1316       1227          2658          3906          5067          3530          1952       1980                318630
# 13           891        391          1062          1491          2619          1298           956       1245                 93289
# 14         12123       9129         23385         28401         37669         26421         16941      18471               2047989
#
#     poverty_totalbelowpoverty  poverty_m65to74  poverty_m75+  poverty_f65to74  poverty_f75+  ed_total_series  ed_m65+  ed_m65+_less9thgrade  \
# 10                        918                0            99               24           128             8917      623                    85
# 11                      10768              147           287              290           565           169365    13993                   419
# 12                      32953              432           318              955           559           244262    14970                   877
# 13                       8414              233           141              310           339            72605     6663                   270
# 14                     226988             4375          2595             7291          6438          1601026   118722                  6875
#
#     ed_m65+9thto12th  ed_m65+_highschoolgradequivalency  ed_m65+_somecollegenodegree  ed_m65+_associates  ed_m65+_bachelors  \
# 10                32                                275                           81                  54                 27
# 11               379                               1748                         2349                 738               4614
# 12              1014                               4118                         3294                 825               2924
# 13               510                               2283                         1624                 517                834
# 14              8367                              32644                        23458                6789              23524
#
#     ed_m65+_graduateorprofessionaldegree  ed_f65+  ed_f65+_less9thgrade  ed_f65+9thto12th  ed_f65+_highschoolgradequivalency  \
# 10                                    69      831                    17               260                                295
# 11                                  3746    16584                   279               978                               3941
# 12                                  1918    19093                   854              1422                               7290
# 13                                   625     8671                   670               963                               3589
# 14                                 17065   151288                  7357             13335                              53526
#
#     ed_f65+_somecollegenodegree  ed_f65+_associates  ed_f65+_bachelors  ed_f65+_graduateorprofessionaldegree  livealone_total65+_series  \
# 10                          148                  91                 12                                     8                       1454
# 11                         3568                1608               3861                                  2349                      30577
# 12                         4493                1367               2038                                  1629                      34063
# 13                         1422                 593                821                                   613                      15334
# 14                        31407                9077              21034                                 15552                     270010
#
#     livealone_total65+_inhh  livealone_m65+  livealone_f65+  grandparent_total_responsibilityforgrandchild_series  \
# 10                     1454             111             288                                                330
# 11                    30577            1653            4617                                               2568
# 12                    34063            2160            5309                                               5623
# 13                    15334            1098            2494                                               1941
# 14                   270010           21089           48026                                              40851
#
#     grandparent_responsibleforgrandchild  grandparent_resposibleforgrandchild_noparent_60+  housing_total_ownercosts  housing_65+total_ownercosts  \
# 10                                   139                                                 0                      2532                          892
# 11                                   774                                               324                     64377                        15827
# 12                                  1601                                               228                     75174                        16455
# 13                                   809                                                98                     25245                         7623
# 14                                 16839                                              2967                    517790                       135808
#
#     housing_65+30to34.9%_ownercosts  housing_65+35%ormore_ownercosts  housing_total_grossrent  housing_65+total_grossrent  \
# 10                               45                              308                      866                          58
# 11                              684                             2610                    16664                        1991
# 12                              828                             2711                    40075                        3573
# 13                              428                             1414                     9918                        1366
# 14                             6986                            23692                   276872                       30704
#
#     housing_65+30to34.9%_grossrent  housing_65+35%ormore_grossrent  socialsecurityhh_total_series  socialsecurityhh_with  socialsecurityhh_without  \
# 10                              19                              10                           3398                   1189                      2209
# 11                             184                            1050                          81041                  19986                     61055
# 12                             286                            1397                         115249                  26726                     88523
# 13                             128                             500                          35163                  11446                     23717
# 14                            2777                           12711                         794662                 208433                    586229
#
#     hhincome_totalhh65+_series  hhincome_65+_lessthan10000  hhincome_65+_10000to14999  hhincome_65+_15000to19999  hhincome_65+_20000to24999  \
# 10                         950                          11                        162                        119                         71
# 11                       17818                         679                        331                        585                        557
# 12                       20028                         912                       1074                       1226                       1002
# 13                        8989                         314                        641                        759                        832
# 14                      166512                        8976                       8954                      10754                       9214
#
#     hhincome_65+_25000to29999  hhincome_65+_30000to34999  hhincome_65+_35000to39999  hhincome_65+_40000to44999  hhincome_65+_45000to49999  \
# 10                         77                         20                          0                         97                         15
# 11                        418                        637                        997                        574                        822
# 12                       1383                        686                       1020                       1498                       1026
# 13                        761                        597                        525                        352                        468
# 14                       9811                       9613                       9104                       9010                       8049
#
#     hhincome_65+_50000to59999  hhincome_65+_60000to74999  hhincome_65+_75000to99999  hhincome_65+_100000to124999  hhincome_65+_125000to149999  \
# 10                        105                        124                         50                           35                           17
# 11                       1870                       2124                       2094                         1477                         1244
# 12                       1878                       2186                       2190                         1610                          798
# 13                        683                        824                        976                          513                          213
# 14                      14114                      17192                      19558                        10788                         6521
#
#     hhincome_65+_150000to199999  hhincome_65+_200000+  tenure_total_agehh_series  tenure_allowneroccupied  tenure_owner_65to74  tenure_owner_75to84  \
# 10                           32                    15                       3398                     2532                  543                  334
# 11                         1094                  2315                      81041                    64377                10436                 4348
# 12                          710                   829                     115249                    75174                10444                 4694
# 13                          252                   279                      35163                    25245                 4722                 2110
# 14                         6129                  8725                     794662                   517790                83893                39704
#
#     tenure_owner_85+  tenure_allrenteroccupied  tenure_renter_65to74  tenure_renter_75to84  tenure_renter_85+ StateFIPS CountyFIPS    Region
# 10                15                       866                    45                     0                 13        47        169  14County
# 11              1043                     16664                   626                   746                619        47        187  14County
# 12              1317                     40075                  2121                  1026                426        47        149  14County
# 13               791                      9918                   952                   282                132        47        119  14County
# 14             12211                    276872                 17704                  8157               4843        47         NA  14County

# %% [markdown]
# # Calculations

# %%
#set cols to float
data[cols] = data[cols].astype(float)

# %% [markdown]
# ## Age

# %% [markdown]
# Add Groups

# %%
data = data.copy()
data['total65+'] = data['age_m_65to66']+data['age_m_67to69']+data['age_m_70to74']+data['age_m_75to79']+data['age_m_80to84']+data['age_m_85+']+data['age_f_65to66']+data['age_f_67to69']+data['age_f_70to74']+data['age_f_75to79']+data['age_f_80to84']+data['age_f_85+']

# %% [markdown]
# Calculate Percentages

# %%
data['%65+'] = round((data['total65+'])*100/data['agebysex_total_series'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['agebysex_total_series','age_m_65to66','age_m_67to69','age_m_70to74',
                            'age_m_75to79','age_m_80to84','age_m_85+','age_f_65to66',
                            'age_f_67to69','age_f_70to74','age_f_75to79','age_f_80to84','age_f_85+'])

# %% [markdown]
# ## Poverty

# %% [markdown]
# Add Groups

# %%
data['poverty65+'] = data['poverty_m65to74']+data['poverty_m75+']+data['poverty_f65to74']+data['poverty_f75+']

# %% [markdown]
# Calculate Percentages

# %%
data['inpoverty65+_%ofbelowpovertylevelpopulation'] = round((data['poverty65+'])*100/data['poverty_totalbelowpoverty'],2)
data['%inpoverty65+'] = round((data['poverty65+'])*100/data['total65+'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['poverty_total_series','poverty_totalbelowpoverty','poverty_m65to74','poverty_m75+',
                            'poverty_f65to74','poverty_f75+'])

# %% [markdown]
# ## Educational Attainment

# %% [markdown]
# Add Groups

# %%
data['edattainment_65+_total'] = data['ed_m65+']+data['ed_f65+']
data['edattainment_65+_lessthan9thgrade'] = data['ed_m65+_less9thgrade']+data['ed_f65+_less9thgrade']
data['edattainment_65+_9thto12thnodiploma'] = data['ed_m65+9thto12th']+data['ed_f65+9thto12th']
data['edattainment_65+_hsgradorequivalency'] = data['ed_m65+_highschoolgradequivalency']+data['ed_f65+_highschoolgradequivalency']
data['edattainment_65+_somecollegenodegree'] = data['ed_m65+_somecollegenodegree']+data['ed_f65+_somecollegenodegree']
data['edattainment_65+_associates'] = data['ed_m65+_associates']+data['ed_f65+_associates']
data['edattainment_65+_bachelors'] = data['ed_m65+_bachelors']+data['ed_f65+_bachelors']
data['edattainment_65+_gradorprofessionaldegree'] = data['ed_m65+_graduateorprofessionaldegree']+data['ed_f65+_graduateorprofessionaldegree']

# %% [markdown]
# Calculate Percentages

# %%
data = data.copy()
data['%65+lessthan9thgrade'] = round((data['edattainment_65+_lessthan9thgrade'])*100/data['edattainment_65+_total'],2)
data['%65+9thto12thnodiploma'] = round((data['edattainment_65+_9thto12thnodiploma'])*100/data['edattainment_65+_total'],2)
data['%65+hsgradorequivalency'] = round((data['edattainment_65+_hsgradorequivalency'])*100/data['edattainment_65+_total'],2)
data['%65+somecollegenodegree'] = round((data['edattainment_65+_somecollegenodegree'])*100/data['edattainment_65+_total'],2)
data['%65+associates'] = round((data['edattainment_65+_associates'])*100/data['edattainment_65+_total'],2)
data['%65+bachelors'] = round((data['edattainment_65+_bachelors'])*100/data['edattainment_65+_total'],2)
data['%65+gradorprofessionaldegree'] = round((data['edattainment_65+_gradorprofessionaldegree'])*100/data['edattainment_65+_total'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['ed_total_series','edattainment_65+_total','ed_m65+','ed_m65+_less9thgrade','ed_m65+9thto12th','ed_m65+_highschoolgradequivalency','ed_m65+_somecollegenodegree','ed_m65+_associates',
        'ed_m65+_bachelors','ed_m65+_graduateorprofessionaldegree','ed_f65+','ed_f65+_less9thgrade','ed_f65+9thto12th','ed_f65+_highschoolgradequivalency',
        'ed_f65+_somecollegenodegree','ed_f65+_associates','ed_f65+_bachelors','ed_f65+_graduateorprofessionaldegree'])

# %% [markdown]
# ## Live Alone

# %% [markdown]
# Add Groups

# %%
data['livealone_65+'] = data['livealone_m65+']+data['livealone_f65+']

# %% [markdown]
# Calculate Percentages

# %%
data['%livealone_65+'] = round((data['livealone_65+'])*100/data['total65+'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['livealone_total65+_series',
        'livealone_total65+_inhh','livealone_m65+','livealone_f65+'])

# %% [markdown]
# ## Responsible for Grandchildren No Parent Present

# %% [markdown]
# Add Groups

# %%
data['grandparent60+_grandchild_noparent'] = data['grandparent_resposibleforgrandchild_noparent_60+']

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['grandparent_total_responsibilityforgrandchild_series','grandparent_responsibleforgrandchild','grandparent_resposibleforgrandchild_noparent_60+'])

# %% [markdown]
# ## Housing Burden

# %% [markdown]
# Add Groups

# %%
data['housingburden_65+'] = data['housing_65+30to34.9%_ownercosts']+data['housing_65+35%ormore_ownercosts']+data['housing_65+30to34.9%_grossrent']+data['housing_65+35%ormore_grossrent']
data['extremehousingburden35%ormore_65+']=data['housing_65+35%ormore_ownercosts']+data['housing_65+35%ormore_grossrent']
data['housingburden_65+_owner'] = data['housing_65+30to34.9%_ownercosts']+data['housing_65+35%ormore_ownercosts']
data['extremehousingburden35%ormore_65+_owner']=data['housing_65+35%ormore_ownercosts']
data['housingburden_65+_renter'] = data['housing_65+30to34.9%_grossrent']+data['housing_65+35%ormore_grossrent']
data['extremehousingburden35%ormore_65+_renter']=data['housing_65+35%ormore_grossrent']

# %% [markdown]
# Calculate Percentages

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['housing_total_ownercosts','housing_65+total_ownercosts','housing_65+30to34.9%_ownercosts',
        'housing_65+35%ormore_ownercosts','housing_total_grossrent','housing_65+total_grossrent','housing_65+30to34.9%_grossrent','housing_65+35%ormore_grossrent'])

# %% [markdown]
# ## Social Security

# %% [markdown]
# Calculate Percentages

# %%
data['%hh_withsocialsecurityincome'] = round((data['socialsecurityhh_with'])*100/data['socialsecurityhh_total_series'],2)
data['%hh_withoutsocialsecurityincome'] = round((data['socialsecurityhh_without'])*100/data['socialsecurityhh_total_series'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['socialsecurityhh_total_series'])

# %% [markdown]
# ## Tenure

# %% [markdown]
# Add Groups

# %%
data['renter_65+'] = data['tenure_renter_65to74']+data['tenure_renter_75to84']+data['tenure_renter_85+']
data['ownerocc_65+'] = data['tenure_owner_65to74']+data['tenure_owner_75to84']+data['tenure_owner_85+']
data['totalhouseholders_65+'] = data['tenure_renter_65to74']+data['tenure_renter_75to84']+data['tenure_renter_85+']+data['tenure_owner_65to74']+data['tenure_owner_75to84']+data['tenure_owner_85+']

# %%
data['%65+_housingburdened'] = round((data['housingburden_65+'])*100/data['total65+'],2)
data['%65+_extremehousingburdened'] = round((data['extremehousingburden35%ormore_65+'])*100/data['total65+'],2)
data['%65+_housingburdened_owner'] = round((data['housingburden_65+_owner'])*100/data['ownerocc_65+'],2)
data['%65+_extremehousingburdened_owner'] = round((data['extremehousingburden35%ormore_65+_owner'])*100/data['ownerocc_65+'],2)
data['%65+_housingburdened_renter'] = round((data['housingburden_65+_renter'])*100/data['renter_65+'],2)
data['%65+_extremehousingburdened_renter'] = round((data['extremehousingburden35%ormore_65+_renter'])*100/data['renter_65+'],2)

# %% [markdown]
# Calculate Percentages

# %%
data['%hh65+_renters'] = round((data['renter_65+'])*100/data['totalhouseholders_65+'],2)
data['%hh65+_ownerocc'] = round((data['ownerocc_65+'])*100/data['totalhouseholders_65+'],2)
data['%allhhrenters_65+'] = round((data['renter_65+'])*100/data['tenure_allrenteroccupied'],2)
data['%allhhownerocc_65+'] = round((data['ownerocc_65+'])*100/data['tenure_allowneroccupied'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['tenure_total_agehh_series','tenure_allowneroccupied','tenure_owner_65to74','tenure_owner_75to84','tenure_owner_85+',
                 'tenure_allrenteroccupied','tenure_renter_65to74','tenure_renter_75to84','tenure_renter_85+'])

# %%
# 'hhincome_totalhh65+_series','hhincome_65+_lessthan10000',
#                  'hhincome_65+_10000to14999','hhincome_65+_15000to19999','hhincome_65+_20000to24999','hhincome_65+_25000to29999','hhincome_65+_30000to34999',
#                  'hhincome_65+_35000to39999','hhincome_65+_40000to44999','hhincome_65+_45000to49999','hhincome_65+_50000to59999','hhincome_65+_60000to74999',
#                  'hhincome_65+_75000to99999','hhincome_65+_100000to124999','hhincome_65+_125000to149999','hhincome_65+_150000to199999','hhincome_65+_200000+',

# %% [markdown]
# ## Income

# %% [markdown]
# Add Groups

# %%
data['hhincome_65+_10000to29999'] = data['hhincome_65+_10000to14999']+data['hhincome_65+_15000to19999']+data['hhincome_65+_20000to24999']+data['hhincome_65+_25000to29999']
data['hhincome_65+_30000to49999']=data['hhincome_65+_30000to34999']+data['hhincome_65+_35000to39999']+data['hhincome_65+_40000to44999']+data['hhincome_65+_45000to49999']
data['hhincome_65+_100000+'] = data['hhincome_65+_100000to124999']+data['hhincome_65+_125000to149999']+data['hhincome_65+_150000to199999']+data['hhincome_65+_200000+']

# %% [markdown]
# Calculate Percentages

# %%
data['%hh65+_incomelesshthan10000']=round((data['hhincome_65+_lessthan10000'])*100/data['hhincome_totalhh65+_series'],2)
data['%hh65+_income10000to29999']=round((data['hhincome_65+_10000to29999'])*100/data['hhincome_totalhh65+_series'],2)
data['%hh65+_income30000to49999']=round((data['hhincome_65+_30000to49999'])*100/data['hhincome_totalhh65+_series'],2)
data['%hh65+_income50000to59999']=round((data['hhincome_65+_50000to59999'])*100/data['hhincome_totalhh65+_series'],2)
data['%hh65+_income60000to74999']=round((data['hhincome_65+_60000to74999'])*100/data['hhincome_totalhh65+_series'],2)
data['%hh65+_income75000to99999']=round((data['hhincome_65+_75000to99999'])*100/data['hhincome_totalhh65+_series'],2)
data['%hh65+_income100000+']=round((data['hhincome_65+_100000+'])*100/data['hhincome_totalhh65+_series'],2)

# %% [markdown]
# Drop Input Columns

# %%
data = data.drop(columns = ['hhincome_65+_100000to124999','hhincome_65+_125000to149999','hhincome_65+_150000to199999','hhincome_65+_200000+',
                            'hhincome_totalhh65+_series','hhincome_65+_10000to14999','hhincome_65+_15000to19999','hhincome_65+_20000to24999',
                            'hhincome_65+_25000to29999','hhincome_65+_30000to34999','hhincome_65+_35000to39999','hhincome_65+_40000to44999',
                            'hhincome_65+_45000to49999'])

# %% [markdown]
# # Export

# %%
data.head()
# Out:
#                          County           GEOID       pop  socialsecurityhh_with  socialsecurityhh_without  hhincome_65+_lessthan10000  \
# 0     Stewart County, Tennessee  0500000US47161   13553.0                 2508.0                    2718.0                        99.0
# 1  Montgomery County, Tennessee  0500000US47125  204992.0                17022.0                   57584.0                       494.0
# 2     Houston County, Tennessee  0500000US47083    8201.0                 1203.0                    1716.0                        86.0
# 3   Humphreys County, Tennessee  0500000US47085   18528.0                 2998.0                    3871.0                       143.0
# 4     Dickson County, Tennessee  0500000US47043   53289.0                 6818.0                   12741.0                       243.0
#
#    hhincome_65+_50000to59999  hhincome_65+_60000to74999  hhincome_65+_75000to99999 StateFIPS CountyFIPS    Region  total65+   %65+  poverty65+  \
# 0                       90.0                      152.0                      225.0        47        161  14County    2678.0  19.76       237.0
# 1                      973.0                      945.0                     1533.0        47        125  14County   19065.0   9.30      1313.0
# 2                       45.0                       30.0                      153.0        47        083  14County    1692.0  20.63       219.0
# 3                      243.0                      162.0                      208.0        47        085  14County    3593.0  19.39       368.0
# 4                      502.0                      518.0                      412.0        47        043  14County    8513.0  15.98       870.0
#
#    inpoverty65+_%ofbelowpovertylevelpopulation  %inpoverty65+  edattainment_65+_lessthan9thgrade  edattainment_65+_9thto12thnodiploma  \
# 0                                        13.37           8.85                               87.0                                316.0
# 1                                         5.32           6.89                             1105.0                               1443.0
# 2                                        18.78          12.94                              151.0                                222.0
# 3                                        13.13          10.24                              203.0                                515.0
# 4                                        13.86          10.22                              920.0                               1044.0
#
#    edattainment_65+_hsgradorequivalency  edattainment_65+_somecollegenodegree  edattainment_65+_associates  edattainment_65+_bachelors  \
# 0                                1276.0                                 430.0                        137.0                       176.0
# 1                                6268.0                                3816.0                       1601.0                      2739.0
# 2                                 801.0                                 247.0                         34.0                       115.0
# 3                                1629.0                                 522.0                         98.0                       356.0
# 4                                3837.0                                1226.0                        301.0                       678.0
#
#    edattainment_65+_gradorprofessionaldegree  %65+lessthan9thgrade  %65+9thto12thnodiploma  %65+hsgradorequivalency  %65+somecollegenodegree  \
# 0                                      256.0                  3.25                   11.80                    47.65                    16.06
# 1                                     2093.0                  5.80                    7.57                    32.88                    20.02
# 2                                      122.0                  8.92                   13.12                    47.34                    14.60
# 3                                      270.0                  5.65                   14.33                    45.34                    14.53
# 4                                      507.0                 10.81                   12.26                    45.07                    14.40
#
#    %65+associates  %65+bachelors  %65+gradorprofessionaldegree  livealone_65+  %livealone_65+  grandparent60+_grandchild_noparent  \
# 0            5.12           6.57                          9.56          794.0           29.65                                81.0
# 1            8.40          14.37                         10.98         4750.0           24.91                               213.0
# 2            2.01           6.80                          7.21          446.0           26.36                                 5.0
# 3            2.73           9.91                          7.51          993.0           27.64                                26.0
# 4            3.54           7.96                          5.96         2126.0           24.97                               112.0
#
#    housingburden_65+  extremehousingburden35%ormore_65+  housingburden_65+_owner  extremehousingburden35%ormore_65+_owner  housingburden_65+_renter  \
# 0              329.0                              267.0                    251.0                                    224.0                      78.0
# 1             2953.0                             2469.0                   1877.0                                   1477.0                    1076.0
# 2              233.0                              200.0                    185.0                                    162.0                      48.0
# 3              530.0                              458.0                    408.0                                    336.0                     122.0
# 4             1053.0                              670.0                    679.0                                    460.0                     374.0
#
#    extremehousingburden35%ormore_65+_renter  %65+_housingburdened  %65+_extremehousingburdened  %65+_housingburdened_owner  \
# 0                                      43.0                 12.29                         9.97                       16.57
# 1                                     992.0                 15.49                        12.95                       19.41
# 2                                      38.0                 13.77                        11.82                       21.74
# 3                                     122.0                 14.75                        12.75                       19.92
# 4                                     210.0                 12.37                         7.87                       15.61
#
#    %65+_extremehousingburdened_owner  %65+_housingburdened_renter  %65+_extremehousingburdened_renter  %hh_withsocialsecurityincome  \
# 0                              14.79                        28.16                               15.52                         47.99
# 1                              15.27                        52.51                               48.41                         22.82
# 2                              19.04                        36.92                               29.23                         41.21
# 3                              16.41                        39.10                               39.10                         43.65
# 4                              10.58                        42.55                               23.89                         34.86
#
#    %hh_withoutsocialsecurityincome  renter_65+  ownerocc_65+  totalhouseholders_65+  %hh65+_renters  %hh65+_ownerocc  %allhhrenters_65+  \
# 0                            52.01       277.0        1515.0                 1792.0           15.46            84.54              21.76
# 1                            77.18      2049.0        9670.0                11719.0           17.48            82.52               7.02
# 2                            58.79       130.0         851.0                  981.0           13.25            86.75              21.78
# 3                            56.35       312.0        2048.0                 2360.0           13.22            86.78              21.08
# 4                            65.14       879.0        4349.0                 5228.0           16.81            83.19              18.83
#
#    %allhhownerocc_65+  hhincome_65+_10000to29999  hhincome_65+_30000to49999  hhincome_65+_100000+  %hh65+_incomelesshthan10000  \
# 0               38.33                      465.0                      641.0                 120.0                         5.52
# 1               21.28                     3352.0                     2577.0                1845.0                         4.22
# 2               36.65                      349.0                      214.0                 104.0                         8.77
# 3               38.00                      571.0                      788.0                 245.0                         6.06
# 4               29.21                     1551.0                     1355.0                 647.0                         4.65
#
#    %hh65+_income10000to29999  %hh65+_income30000to49999  %hh65+_income50000to59999  %hh65+_income60000to74999  %hh65+_income75000to99999  \
# 0                      25.95                      35.77                       5.02                       8.48                      12.56
# 1                      28.60                      21.99                       8.30                       8.06                      13.08
# 2                      35.58                      21.81                       4.59                       3.06                      15.60
# 3                      24.19                      33.39                      10.30                       6.86                       8.81
# 4                      29.67                      25.92                       9.60                       9.91                       7.88
#
#    %hh65+_income100000+
# 0                  6.70
# 1                 15.74
# 2                 10.60
# 3                 10.38
# 4                 12.38

# %%
transp = data.transpose()

# %%
transp.columns = transp.iloc[0]

# %%
transp.head()
# Out:
# County                    Stewart County, Tennessee  Montgomery County, Tennessee  Houston County, Tennessee  Humphreys County, Tennessee  \
# County                    Stewart County, Tennessee  Montgomery County, Tennessee  Houston County, Tennessee  Humphreys County, Tennessee
# GEOID                                0500000US47161                0500000US47125             0500000US47083               0500000US47085
# pop                                         13553.0                      204992.0                     8201.0                      18528.0
# socialsecurityhh_with                        2508.0                       17022.0                     1203.0                       2998.0
# socialsecurityhh_without                     2718.0                       57584.0                     1716.0                       3871.0
#
# County                    Dickson County, Tennessee  Cheatham County, Tennessee  Robertson County, Tennessee  Sumner County, Tennessee  \
# County                    Dickson County, Tennessee  Cheatham County, Tennessee  Robertson County, Tennessee  Sumner County, Tennessee
# GEOID                                0500000US47043              0500000US47021               0500000US47147            0500000US47165
# pop                                         53289.0                     40539.0                      70982.0                  187680.0
# socialsecurityhh_with                        6818.0                      4981.0                       8296.0                   22148.0
# socialsecurityhh_without                    12741.0                     10336.0                      17826.0                   46506.0
#
# County                    Davidson County, Tennessee  Wilson County, Tennessee  Trousdale County, Tennessee  Williamson County, Tennessee  \
# County                    Davidson County, Tennessee  Wilson County, Tennessee  Trousdale County, Tennessee  Williamson County, Tennessee
# GEOID                                 0500000US47037            0500000US47189               0500000US47169                0500000US47187
# pop                                         690540.0                  140604.0                      10910.0                      232380.0
# socialsecurityhh_with                        67064.0                   16048.0                       1189.0                       19986.0
# socialsecurityhh_without                    222127.0                   35300.0                       2209.0                       61055.0
#
# County                    Rutherford County, Tennessee  Maury County, Tennessee        All
# County                    Rutherford County, Tennessee  Maury County, Tennessee        All
# GEOID                                   0500000US47149           0500000US47119         NA
# pop                                           324139.0                  94615.0  2090952.0
# socialsecurityhh_with                          26726.0                  11446.0   208433.0
# socialsecurityhh_without                       88523.0                  23717.0   586229.0

# %%
transp = transp.loc[transp['Stewart County, Tennessee'] != 'Stewart County, Tennessee']

# %%
transp = transp.loc[transp['Stewart County, Tennessee'] != 'Stewart County, Tennessee']

# %%
#write to csv
transp.to_csv('../data/agewellhousing.csv')
